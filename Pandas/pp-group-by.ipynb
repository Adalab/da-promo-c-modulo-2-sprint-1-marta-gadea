# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Ejercicio 1.
# ¿Cuántos ataques hubo por país? Devuelve un DataFrame.
# 📌 NOTA Ordena los resultados de mayor a menor. Esto todavía no lo hemos visto, pero un DataFrame lo podemos ordenar con .sort_values(). Aquí tenéis una explicación de cómo hacerlo.

# %%
attacks = pd.read_csv('../Pandas/attacks_1_4.csv')
attacks.head(3)
# Out:
#     case_number    year        type country        area  \
# 0    2018.06.25  2018.0     Boating     USA  California
# 1  2018.06.03.a  2018.0  Unprovoked  BRAZIL  Pernambuco
# 2  2018.05.26.b  2018.0  Unprovoked     USA     Florida
#
#                        location  activity                    name sex age  \
# 0   Oceanside, San Diego County  Paddling             Julie Wolfe   F  57
# 1         Piedade Beach, Recife  Swimming  Jose Ernesto da Silva    M  18
# 2  Cocoa Beach, Brevard  County   Walking               Cody High   M  15
#
#              time         species                       pdf  \
# 0           18h00     White shark      2018.06.25-Wolfe.pdf
# 1  Late afternoon     Tiger shark  2018.06.03.a-daSilva.pdf
# 2           17h00  Bull shark, 6'     2018.05.26.b-High.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
attacks.columns
# Out:
# Index(['case_number', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'time', 'species', 'pdf',
#        'href_formula', 'href', 'siglo', 'case_number.1', 'fatal_(y/n)',
#        'injury', 'date'],
#       dtype='object')

# %%
paises = attacks['country'].value_counts()
paises = paises.reset_index()
paises.sort_values(by='country', ascending=False)
# Out:
#                  index  country
# 0                  USA      741
# 1            AUSTRALIA      343
# 2         SOUTH AFRICA      234
# 3              BAHAMAS       29
# 4          NEW ZEALAND       21
# ..                 ...      ...
# 67            RED SEA?        1
# 68           SINGAPORE        1
# 69          MADAGASCAR        1
# 70           NICARAGUA        1
# 94  CEYLON (SRI LANKA)        1
#
# [95 rows x 2 columns]

# %% [markdown]
# ### Ejercicio 2.
# ¿Cuántos ataques ha habido por año? Devuelve un DataFrame. De nuevo ordena los resultados de mayor a menor.

# %%
#añadimos el head() al final ya que de lo contrario nos enseña todas las filas independientemente de lo que le pidamos X desde el método .head()
#https://stackoverflow.com/a/36074520
attack_per_year = attacks.sort_values(['year'], ascending=False).groupby('year').head() 
attack_per_year.head(3)
# Out:
#     case_number    year        type       country                   area  \
# 0    2018.06.25  2018.0     Boating           USA             California
# 9    2018.04.03  2018.0  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 1  2018.06.03.a  2018.0  Unprovoked        BRAZIL             Pernambuco
#
#                       location  activity                    name sex age  \
# 0  Oceanside, San Diego County  Paddling             Julie Wolfe   F  57
# 9              St. Francis Bay   Surfing            Ross Spowart   M  19
# 1        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva    M  18
#
#              time      species                          pdf  \
# 0           18h00  White shark         2018.06.25-Wolfe.pdf
# 9           15h00  White shark  2018.04.03-StFrancisBay.pdf
# 1  Late afternoon  Tiger shark     2018.06.03.a-daSilva.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %% [markdown]
# ### Ejercicio 3.
# ¿Cuántos ataques hubo por año y sexo? Devolved un DataFrame solo del año 2000 en adelante.

# %%
year2000 = attacks[attacks['year'] >= 2000]
ejercicio3 = year2000.groupby('year')['sex']

df_ejercicio3 = ejercicio3.count().reset_index()
df_ejercicio3
# Out:
#       year  sex
# 0   2000.0   33
# 1   2001.0   29
# 2   2002.0   53
# 3   2003.0   44
# 4   2004.0   40
# 5   2005.0   45
# 6   2006.0   40
# 7   2007.0   57
# 8   2008.0   40
# 9   2009.0   42
# 10  2010.0   37
# 11  2011.0   36
# 12  2012.0   54
# 13  2013.0   48
# 14  2014.0   35
# 15  2015.0   68
# 16  2016.0   37
# 17  2017.0   30
# 18  2018.0   17

# %% [markdown]
# ### Ejercicio 4.
# Primero extraed solo las filas que correspondan a USA, AUSTRALIA y SOUTH AFRICA. ¿Cuántos de los ataques fueron letales por sexo? Devuelve un DataFrame.

# %%
lista_paises = ['USA', 'AUSTRALIA', 'SOUTH AFRICA']
attacks_por_pais = attacks[attacks['country'].isin(lista_paises)]

# %%
letales = np.where(attacks_por_pais['fatal_(y/n)'] == 'Y')
sexo = np.where(attacks_por_pais['sex'])

# %%
attacks_por_pais.groupby(letales, sexo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 attacks_por_pais.groupby(letales, sexo)
#
# File c:\Users\PcCom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8397, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8395 if level is None and by is None:
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8397 axis = self._get_axis_number(axis)
#    8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    (...)
#    8409     dropna=dropna,
#    8410 )
#
# File c:\Users\PcCom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# ...

# %%
df_letal = attacks_por_pais[(attacks_por_pais['fatal_(y/n)'] == 'Y')]
df_letal.head(3)
# Out:
#      case_number    year        type    country               area  \
# 6   2018.04.25.a  2018.0  Unprovoked  AUSTRALIA  Western Australia
# 58    2016.08.06  2016.0  Unprovoked        USA             Hawaii
# 64  2016.06.21.b  2016.0  Unprovoked        USA     South Carolina
#
#                             location           activity           name sex  \
# 6            Surfers Point, Prevelly            Surfing      Rob Bruce   M
# 58                              Maui  SUP Foil boarding  Connor Baxter   M
# 64  North Myrtle Beach, Horry County           Floating    Jeff Schott   M
#
#    age   time            species                      pdf  \
# 6   60  09h30          3 m shark   2018.04.25.a-Bruce.pdf
# 58  21  16h30  Tiger shark, 10'     2016.08.06-Baxter.pdf
# 64  42  15h25     3' to 5' shark  2016.06.21.b-Schott.pdf
#
#                                          href_formula  \
# 6   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
#ataques por sexo:
df_letal['sex'].value_counts()
# Out:
#   index  sex
# 0     M   90
# 1     F    7

# %% [markdown]
# ### Ejercicio 5.
# Usando el DataFrame creado en el ejercicio anterior. ¿En qué país hubo más ataques?

# %%
ej5 = attacks_por_pais['country'].value_counts()
print(f'La mayoría de ataques tuvo lugar en {ej5.keys()[0]}, con un total de {ej5[0]} ataques.')
# Out:
# La mayoría de ataques tuvo lugar en USA, con un total de 741 ataques.

# %% [markdown]
# ### Ejercicio 6.
# ¿Qué y cuántos tipos de ataques hubo por país?

# %%
ej6 = attacks.sort_values(['type'], ascending=False).groupby('country').head()
ej6.head(3)
# Out:
#        case_number    year        type country     area  \
# 836   1997.10.28.a  1997.0  Unprovoked     USA   Hawaii
# 1097  1981.10.19.a  1981.0  Unprovoked     USA  Florida
# 1064  1984.07.24.a  1984.0  Unprovoked     USA    Texas
#
#                                                location  \
# 836   Waiokapua Bay/Majors Bay, Brennecke Beach, Poi...
# 1097                     Jupiter Island, Brevard County
# 1064                                 South Padre Island
#
#                       activity           name sex age   time  \
# 836   Body boarding or surfing     Mike Coots   M  19  07h20
# 1097                  Swimming   Van Horn Ely   M  19  11h30
# 1064                  Swimming  Carmen Gaytan   F  18  12h00
#
#                                       species                          pdf  \
# 836   Tiger shark, 4 m to 4.3 m [13' to 14']        1997.10.28.a-Coots.pdf
# 1097          1.8 m to 2.4 m [6' to 8'] shark  1981.10.19.a-VanHornEly.pdf
# ...
