# %%
import pandas as pd

# %% [markdown]
# ### Ejercicio 1
# Cargar el dataset

# %% [markdown]
# Pista: Si hacemos la carga del dataset sin el parámetro encoding nos puede dar error (puede que no os de error, si es así menos problemas!). Aquí tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO

# %%
db_sharks = pd.read_csv('../Pandas/attacks.csv')

# %%
db_sharks.head(10)
# Out:
#    Unnamed: 0   Case Number    Year        Type    Country             Area  \
# 0           0    2018.06.25  2018.0     Boating        USA       California
# 1           1    2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2    2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3    2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4    2018.06.04  2018.0    Provoked     MEXICO           Colima
# 5           5  2018.06.03.b  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6           6  2018.06.03.a  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7           7    2018.05.27  2018.0  Unprovoked        USA          Florida
# 8           8  2018.05.26.b  2018.0  Unprovoked        USA          Florida
# 9           9  2018.05.26.a  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# ...

# %% [markdown]
# ### Ejercicio 2
# Haced una exploración básica del DataFrame:

# %% [markdown]
# * ¿Cuántas filas y columnas tiene el DataFrame?

# %%
db_sharks.shape
# Out:
# (6114, 22)

# %% [markdown]
# * Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.

# %%
#https://stackoverflow.com/questions/58260771/how-to-show-firstlast-n-rows-of-a-dataframe

head_tail =pd.concat([db_sharks.head(5),db_sharks.tail(5)]) 
head_tail
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# 2                Hawaii                      Habush, Oahu
# ...

# %% [markdown]
# * Mostrad 2 filas al azar del DataFrame.

# %%
db_sharks.sample(2)
# Out:
#       Unnamed: 0   Case Number    Year        Type     Country  \
# 5100        5112  1928.02.00.b  1928.0  Unprovoked  COSTA RICA
# 21            21  2018.04.25.a  2018.0  Unprovoked   AUSTRALIA
#
#                    Area                 Location  Activity          Name Sex   \
# 5100    Near Puntarenas                      NaN  Swimming  Lily Artavia    F
# 21    Western Australia  Surfers Point, Prevelly   Surfing     Rob Bruce    M
#
#       ...   Species        Investigator or Source                       pdf  \
# 5100  ...        NaN  Gleaner (Jamaica), 3/7/1928  1928.02.00.b-Artavia.pdf
# 21    ...  3 m shark                B.Myatt, GSAF    2018.04.25.a-Bruce.pdf
#
#                                            href formula  \
# 5100  http://sharkattackfile.net/spreadsheets/pdf_di...
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# ...

# %% [markdown]
# * ¿Cuál es el nombre de las columnas del DataFrame?

# %%
db_sharks.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# * ¿Cuáles son los principales estádisticos del DataFrame?
#   Mostrad por separado las variables categóricas y las variables numéricas.

# %% [markdown]
#         Númericas

# %%
db_sharks.describe()
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %% [markdown]
#         Categóricas

# %%
db_sharks.describe(include=object)
# Out:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# ...

# %% [markdown]
# * ¿Cuál es el porcentaje de valores nulos en cada columna?

# %%
#se puede hacer también de la siguiente forma:
db_sharks.isnull().sum()*100/len(db_sharks)
# Out:
# Unnamed: 0                 0.000000
# Case Number                0.016356
# Year                       0.000000
# Type                       0.065424
# Country                    0.654236
# Area                       6.673209
# Location                   7.981681
# Activity                   8.357867
# Name                       3.271181
# Sex                        8.995747
# Age                       43.604841
# Time                      52.011776
# Species                   44.242722
# Investigator or Source     0.261694
# pdf                        0.000000
# href formula               0.016356
# href                       0.000000
# Case Number.1              0.000000
# Case Number.2              0.000000
# original order             0.000000
# Unnamed: 22               99.983644
# Unnamed: 23               99.967288
# dtype: float64

# %%
db_sharks.isnull().mean()*100
# Out:
# Unnamed: 0                 0.000000
# Case Number                0.016356
# Year                       0.000000
# Type                       0.065424
# Country                    0.654236
# Area                       6.673209
# Location                   7.981681
# Activity                   8.357867
# Name                       3.271181
# Sex                        8.995747
# Age                       43.604841
# Time                      52.011776
# Species                   44.242722
# Investigator or Source     0.261694
# pdf                        0.000000
# href formula               0.016356
# href                       0.000000
# Case Number.1              0.000000
# Case Number.2              0.000000
# original order             0.000000
# Unnamed: 22               99.983644
# Unnamed: 23               99.967288
# dtype: float64

# %% [markdown]
# * Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.

# %%
columnas= db_sharks.columns
columnas
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
dict_sharks = {}

# %%
db_sharks["Location"].value_counts()
# Out:
# New Smyrna Beach, Volusia County                             162
# Daytona Beach, Volusia County                                 30
# Ponce Inlet, Volusia County                                   20
# Melbourne Beach, Brevard County                               18
# Myrtle Beach, Horry County                                    17
#                                                             ...
# Ocean Beach, Jaycee Park, Vero Beach, Indian River County      1
# South Beach Park, Indian River County                          1
# 460 miles off Iwakuni                                          1
#  Boa Viagem Beach, Recife                                      1
# Hamelin Harbour, at Faure Island                               1
# Name: Location, Length: 4020, dtype: int64

# %%
for i in db_sharks:
    print(db_sharks[i].unique)
# Out:
# <bound method Series.unique of 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 6109    6127
# 6110    6128
# 6111    6129
# 6112    6130
# 6113    6131
# Name: Unnamed: 0, Length: 6114, dtype: int64>
# <bound method Series.unique of 0         2018.06.25
# 1         2018.06.18
# 2         2018.06.09
# 3         2018.06.08
# 4         2018.06.04
#             ...
# 6109    1804.02.26.R
# 6110      1803.05.17
# 6111      1803.03.00
# 6112    1802.04.13.R
# 6113    1801.12.18.R
# Name: Case Number, Length: 6114, dtype: object>
# <bound method Series.unique of 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6109    1804.0
# 6110    1803.0
# 6111    1803.0
# 6112    1802.0
# 6113    1801.0
# Name: Year, Length: 6114, dtype: float64>
# <bound method Series.unique of 0            Boating
# 1         Unprovoked
# 2            Invalid
# 3         Unprovoked
# 4           Provoked
#             ...
# ...
