# %%
import pandas as pd

# %%
db_sharks = pd.read_csv('../Pandas/Archivos/attacks.csv', encoding='UTF-8')
db_sharks.head(2)
# Out:
#    Unnamed: 0 Case Number    Year        Type Country        Area  \
# 0           0  2018.06.25  2018.0     Boating     USA  California
# 1           1  2018.06.18  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  ...
#
#       Species           Investigator or Source                     pdf  \
# 0  White shark                R. Collier, GSAF    2018.06.25-Wolfe.pdf
# 1          NaN  K.McMurray, TrackingSharks.com  2018.06.18-McNeely.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...

# %%
db_sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6114 entries, 0 to 6113
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              6114 non-null   int64
#  1   Case Number             6113 non-null   object
#  2   Year                    6114 non-null   float64
#  3   Type                    6110 non-null   object
#  4   Country                 6074 non-null   object
#  5   Area                    5706 non-null   object
#  6   Location                5626 non-null   object
#  7   Activity                5603 non-null   object
#  8   Name                    5914 non-null   object
#  9   Sex                     5564 non-null   object
#  10  Age                     3448 non-null   object
#  11  Time                    2934 non-null   object
#  12  Species                 3409 non-null   object
#  13  Investigator or Source  6098 non-null   object
# ...

# %% [markdown]
# ### Ejercicio 2
# Haced una exploración básica del DataFrame:

# %% [markdown]
# * ¿Cuántas filas y columnas tiene el DataFrame?

# %%
print(f'El DataFrame tiene {db_sharks.shape[0]} filas y {db_sharks.shape[1]} columnas.')
# Out:
# El DataFrame tiene 6114 filas y 22 columnas.

# %% [markdown]
# * Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.

# %% [markdown]
# *   Primeras cinco filas:

# %%
#primeras cinco filas. no sería necesario especificar el 5 ya que, por defecto, head() devuelve las 5 primeras filas.
db_sharks.head(5)
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# * Primeras últimas filas:

# %%
#al igual que head, tail devuelve por defecto las 5 primeras filas:
db_sharks.tail()
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# ...

# %% [markdown]
# * Devuelve dos filas al azar:

# %%
db_sharks.sample(2)
# Out:
#       Unnamed: 0   Case Number    Year        Type    Country        Area  \
# 5001        5013    1931.08.01  1931.0  Unprovoked  AUSTRALIA  Queensland
# 4910        4922  1935.01.24.a  1935.0     Boating  AUSTRALIA  Queensland
#
#                     Location            Activity                Name Sex   \
# 5001            Port Douglas     Fell overboard?   Llewellyn Roberts    M
# 4910  Ross River, Townsville  Fishing for sharks  flat-bottomed boat  NaN
#
#       ...  Species                Investigator or Source  \
# 5001  ...       NaN  Townsville Daily Bulletin, 8/4/1931
# 4910  ...  2 sharks                  G.P. Whitley, p.263
#
#                                       pdf  \
# 5001               1931.08.01-Roberts.pdf
# 4910  1935.01.24.a-Flat-bottomed-boat.pdf
#
#                                            href formula  \
# 5001  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4910  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# ...

# %% [markdown]
# * ¿Cuál es el nombre de las columnas del DataFrame?

# %%
db_sharks.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# * ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

# %%
#variables numéricas
db_sharks.describe()
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %%
#variables categóricas
db_sharks.describe(include=object)
# Out:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# ...

# %% [markdown]
#         Nos pasa lo siguiente que no sabemos como resolver: Sobre los originales se guardan los cambios aplicados con el .strip() pero no con las copias. Por ello, hemos optado por quitar primero los espacios y luego hacer la copia.

# %%
#vamos a quitar primero los espacios que hay después de cada nombre de columna:
#https://stackoverflow.com/a/41476181
db_sharks.columns = db_sharks.columns.str.strip()

# %%
#pendiente hacer un regex con los espacios al final de los nombres de las columnas para que los reemplace por "".
db_sharks.columns = db_sharks.columns.str.replace(" ", "_").str.lower()
db_sharks.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex', 'age', 'time', 'species',
#        'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number.1', 'case_number.2', 'original_order', 'unnamed:_22',
#        'unnamed:_23'],
#       dtype='object')

# %%
db_sharks2 = db_sharks.copy()
db_sharks2.columns
# Out:
# Index(['Unnamed:_0', 'Case_Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex', 'Age', 'Time', 'Species',
#        'Investigator_or_Source', 'pdf', 'href_formula', 'href',
#        'Case_Number.1', 'Case_Number.2', 'original_order', 'Unnamed:_22',
#        'Unnamed:_23'],
#       dtype='object')

# %% [markdown]
# * Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

# %%
db_sharks2.drop(['Unnamed:_0', 'Investigator_or_Source', 'Case_Number.1', 'Case_Number.2', 'original_order', 'Unnamed:_22',
       'Unnamed:_23'], inplace=True, axis=1)
db_sharks2.columns
# Out:
# Index(['Case_Number', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Time', 'Species', 'pdf',
#        'href_formula', 'href'],
#       dtype='object')

# %% [markdown]
# * Estableced la columna 'case_number' como índice del dataframe:

# %%
db_sharks2.set_index('case_number', inplace=True)
db_sharks2.head()
# Out:
#              year        type    country             area  \
# case_number
# 2018.06.25   2018     Boating        USA       California
# 2018.06.18   2018  Unprovoked        USA          Georgia
# 2018.06.09   2018     Invalid        USA           Hawaii
# 2018.06.08   2018  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04   2018    Provoked     MEXICO           Colima
#
#                                    location     activity             name sex  \
# case_number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe   F
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely    F
# 2018.06.09                     Habush, Oahu      Surfing      John Denges   M
# 2018.06.08               Arrawarra Headland      Surfing             male   M
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos    M
#
#              age           time          species                       pdf  \
# case_number
# ...

# %% [markdown]
# ### Ejercicio 3.
# Guarda el csv que no tiene esas columnas para seguir usándolo mañana.

# %% [markdown]
# * Por último, ¡guardamos los datos en un nuevo csv! Le cambiamos el nombre a esta versión para tener trazabilidad de los cambios aplicados en el DataFrame:

# %%
db_csv = db_sharks2.to_csv('../Pandas/attacks_1_2.csv')
db_csv
